# %% [markdown]
# # 05 — Results & Baseline Comparison
#
# ML pipeline vs. Reasenberg (1985): cluster counts, declustered catalog size, Kolmogorov-Smirnov test of inter-event times against exponential, headline figures for the report.
#
# See `PROJECT_PROPOSAL.md` sections 7 (Phase H) and 10.
