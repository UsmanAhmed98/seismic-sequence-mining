# %% [markdown]
# # 04 — Classification
#
# SVM, Decision Tree, Naive Bayes for event-type classification; KNN for aftershock magnitude estimation; LDA for 2D projection.
#
# See `PROJECT_PROPOSAL.md` section 7 (Phases F-G).
