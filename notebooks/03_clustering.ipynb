# %% [markdown]
# # 03 — Clustering / Declustering
#
# DBSCAN and ST-DBSCAN parameter sweep, silhouette diagnostics, recovery of known sequences (Kashmir 2005, Awaran 2013, Hindu Kush 2015), background regime profiling with K-means.
#
# See `PROJECT_PROPOSAL.md` section 7 (Phases D-E).
